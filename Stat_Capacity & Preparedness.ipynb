# %%
import pandas as pd

# %%
stat_capacity_df = pd.read_csv("https://raw.githubusercontent.com/Amould1/Project_2/master/stat_capacity.csv")
stat_capacity_df
# Out:
#      Country Name Country Code                                Indicator Name  \
# 0           Aruba          ABW  Statistical Capacity score (Overall average)
# 1     Afghanistan          AFG  Statistical Capacity score (Overall average)
# 2          Angola          AGO  Statistical Capacity score (Overall average)
# 3         Albania          ALB  Statistical Capacity score (Overall average)
# 4         Andorra          AND  Statistical Capacity score (Overall average)
# ..            ...          ...                                           ...
# 259        Kosovo          XKX  Statistical Capacity score (Overall average)
# 260   Yemen, Rep.          YEM  Statistical Capacity score (Overall average)
# 261  South Africa          ZAF  Statistical Capacity score (Overall average)
# 262        Zambia          ZMB  Statistical Capacity score (Overall average)
# 263      Zimbabwe          ZWE  Statistical Capacity score (Overall average)
#
#     Indicator Code  1960  1961  1962  1963  1964  1965  ...       2010  \
# 0      IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 1      IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  52.222222
# 2      IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  45.555556
# 3      IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  70.000000
# 4      IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# ..             ...   ...   ...   ...   ...   ...   ...  ...        ...
# 259    IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...        NaN
# 260    IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  48.888889
# 261    IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  82.222222
# 262    IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  57.777778
# 263    IQ.SCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...  51.111111
#
#           2011       2012       2013       2014       2015       2016  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1    51.111111  50.000000  53.333333  54.444444  51.111100  51.111100
# 2    47.777778  50.000000  47.777778  48.888889  47.777767  42.222167
# 3    70.000000  73.333333  68.888889  75.555556  72.222233  82.222233
# 4          NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 259        NaN        NaN  30.000000  33.333333  40.000000  43.333333
# 260  47.777778  46.666667  52.222222  55.555556  55.555600  47.777833
# 261  81.111111  72.222222  76.666667  74.444444  81.111100  82.222233
# 262  60.000000  62.222222  56.666667  60.000000  60.000033  53.333367
# 263  54.444444  53.333333  54.444444  57.777778  62.222200  55.555533
#
#           2017       2018  2019
# 0          NaN        NaN   NaN
# 1    51.111100  50.000000   NaN
# 2    45.555500  52.222233   NaN
# 3    88.888900  88.888900   NaN
# 4          NaN        NaN   NaN
# ..         ...        ...   ...
# 259  43.333333  40.000000   NaN
# 260  44.444467  37.777833   NaN
# 261  75.555567  82.222233   NaN
# 262  52.222233  62.222233   NaN
# 263  59.999967  66.666633   NaN
#
# [264 rows x 64 columns]

# %%
stat_capacity_df_clean = stat_capacity_df.drop(["Indicator Code", "Indicator Name", "1960",
                                                "1961", "1962", "1963", "1964", "1965", "1966", "1967", "1968",
                                               "1969",  "1970","1971", "1972", "1973", "1974", "1975", "1976", "1977",
                                                "1978", "1979", "1980", "1981", "1982", "1983", "1984", "1985", "1986",
                                                "1987", "1988", "1989", "1990", "1991", "1992", "1993", "1994", "1995", 
                                                "1996", "1997", "1998","1999", "2000", "2001", "2002", "2003", "2003",
                                                "2004", "2005", "2006", "2007", "2008", "2009", "2019"], axis=1)
stat_capacity_df_clean
# Out:
#      Country Name Country Code       2010       2011       2012       2013  \
# 0           Aruba          ABW        NaN        NaN        NaN        NaN
# 1     Afghanistan          AFG  52.222222  51.111111  50.000000  53.333333
# 2          Angola          AGO  45.555556  47.777778  50.000000  47.777778
# 3         Albania          ALB  70.000000  70.000000  73.333333  68.888889
# 4         Andorra          AND        NaN        NaN        NaN        NaN
# ..            ...          ...        ...        ...        ...        ...
# 259        Kosovo          XKX        NaN        NaN        NaN  30.000000
# 260   Yemen, Rep.          YEM  48.888889  47.777778  46.666667  52.222222
# 261  South Africa          ZAF  82.222222  81.111111  72.222222  76.666667
# 262        Zambia          ZMB  57.777778  60.000000  62.222222  56.666667
# 263      Zimbabwe          ZWE  51.111111  54.444444  53.333333  54.444444
#
#           2014       2015       2016       2017       2018
# 0          NaN        NaN        NaN        NaN        NaN
# 1    54.444444  51.111100  51.111100  51.111100  50.000000
# 2    48.888889  47.777767  42.222167  45.555500  52.222233
# 3    75.555556  72.222233  82.222233  88.888900  88.888900
# 4          NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...
# 259  33.333333  40.000000  43.333333  43.333333  40.000000
# 260  55.555556  55.555600  47.777833  44.444467  37.777833
# 261  74.444444  81.111100  82.222233  75.555567  82.222233
# 262  60.000000  60.000033  53.333367  52.222233  62.222233
# 263  57.777778  62.222200  55.555533  59.999967  66.666633
#
# [264 rows x 11 columns]

# %%
final_stat_capacity_df = stat_capacity_df_clean.rename(columns={'2010': '2010 : Stat Capacity Score',
                                                                '2011': '2011 : Stat Capacity Score',
                                                                '2012': '2012 : Stat Capacity Score',
                                                                '2013': '2013 : Stat Capacity Score',
                                                                '2014': '2014 : Stat Capacity Score',
                                                                '2015': '2015 : Stat Capacity Score',
                                                                '2016': '2016 : Stat Capacity Score',
                                                                '2017': '2017 : Stat Capacity Score',
                                                                '2018': '2018 : Stat Capacity Score',})
final_stat_capacity_df
# Out:
#      Country Name Country Code  2010 : Stat Capacity Score  \
# 0           Aruba          ABW                         NaN
# 1     Afghanistan          AFG                   52.222222
# 2          Angola          AGO                   45.555556
# 3         Albania          ALB                   70.000000
# 4         Andorra          AND                         NaN
# ..            ...          ...                         ...
# 259        Kosovo          XKX                         NaN
# 260   Yemen, Rep.          YEM                   48.888889
# 261  South Africa          ZAF                   82.222222
# 262        Zambia          ZMB                   57.777778
# 263      Zimbabwe          ZWE                   51.111111
#
#      2011 : Stat Capacity Score  2012 : Stat Capacity Score  \
# 0                           NaN                         NaN
# 1                     51.111111                   50.000000
# 2                     47.777778                   50.000000
# 3                     70.000000                   73.333333
# 4                           NaN                         NaN
# ..                          ...                         ...
# 259                         NaN                         NaN
# 260                   47.777778                   46.666667
# 261                   81.111111                   72.222222
# 262                   60.000000                   62.222222
# 263                   54.444444                   53.333333
#
#      2013 : Stat Capacity Score  2014 : Stat Capacity Score  \
# 0                           NaN                         NaN
# 1                     53.333333                   54.444444
# 2                     47.777778                   48.888889
# 3                     68.888889                   75.555556
# 4                           NaN                         NaN
# ..                          ...                         ...
# 259                   30.000000                   33.333333
# 260                   52.222222                   55.555556
# 261                   76.666667                   74.444444
# 262                   56.666667                   60.000000
# 263                   54.444444                   57.777778
#
#      2015 : Stat Capacity Score  2016 : Stat Capacity Score  \
# 0                           NaN                         NaN
# 1                     51.111100                   51.111100
# 2                     47.777767                   42.222167
# 3                     72.222233                   82.222233
# 4                           NaN                         NaN
# ..                          ...                         ...
# 259                   40.000000                   43.333333
# 260                   55.555600                   47.777833
# 261                   81.111100                   82.222233
# 262                   60.000033                   53.333367
# 263                   62.222200                   55.555533
#
#      2017 : Stat Capacity Score  2018 : Stat Capacity Score
# 0                           NaN                         NaN
# 1                     51.111100                   50.000000
# 2                     45.555500                   52.222233
# 3                     88.888900                   88.888900
# 4                           NaN                         NaN
# ..                          ...                         ...
# 259                   43.333333                   40.000000
# 260                   44.444467                   37.777833
# 261                   75.555567                   82.222233
# 262                   52.222233                   62.222233
# 263                   59.999967                   66.666633
#
# [264 rows x 11 columns]

# %%
preparedness = pd.read_csv("https://raw.githubusercontent.com/Amould1/Project_2/master/Preparedness_data.csv")

# %%
preparedness.head()
# Out:
#        Country  2017  2016  2015 2014 2013 2012 2011 2010
# 0  Afghanistan  55.0  28.0  18.0   26   10    0    0   41
# 1      Albania   8.0   NaN   NaN  NaN  NaN  NaN  NaN  NaN
# 2      Algeria  80.0  63.0  80.0   80   61   10    0   46
# 3      Andorra   8.0   8.0   8.0    8    8   40   10   12
# 4       Angola  90.0   NaN   NaN    0   25  NaN   20  NaN

# %%
codes = pd.read_csv("https://raw.githubusercontent.com/lukes/ISO-3166-Countries-with-Regional-Codes/master/all/all.csv")
codes.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
codes_limited = codes[["alpha-3", "name"]]
codes_limited.columns = ["Country Code", "Country"]
codes_limited.head()
# Out:
#   Country Code         Country
# 0          AFG     Afghanistan
# 1          ALA   Åland Islands
# 2          ALB         Albania
# 3          DZA         Algeria
# 4          ASM  American Samoa

# %%
preparedness_codes = preparedness.merge(codes_limited, how = "inner",  on = "Country")
new_preparedness_codes = preparedness_codes.rename(columns={'2010': '2010 : Preparedness Score',
                                                                '2011': '2011 : Preparedness Score',
                                                                '2012': '2012 : Preparedness Score',
                                                                '2013': '2013 : Preparedness Score',
                                                                '2014': '2014 : Preparedness Score',
                                                                '2015': '2015 : Preparedness Score',
                                                                '2016': '2016 : Preparedness Score',
                                                                '2017': '2017 : Preparedness Score',})

# %%
combined_df = new_preparedness_codes.merge(final_stat_capacity_df, how = "inner",  on = "Country Code")
new_combined = combined_df.drop(["2018 : Stat Capacity Score", "Country"], axis=1)
new_combined
# Out:
#      2017 : Preparedness Score  2016 : Preparedness Score  \
# 0                         55.0                       28.0
# 1                          8.0                        NaN
# 2                         80.0                       63.0
# 3                          8.0                        8.0
# 4                         90.0                        NaN
# ..                         ...                        ...
# 181                      100.0                      100.0
# 182                       92.0                      100.0
# 183                       10.0                        NaN
# 184                       73.0                        NaN
# 185                       53.0                       80.0
#
#      2015 : Preparedness Score 2014 : Preparedness Score  \
# 0                         18.0                        26
# 1                          NaN                       NaN
# 2                         80.0                        80
# 3                          8.0                         8
# 4                          NaN                         0
# ..                         ...                       ...
# 181                      100.0                       100
# 182                      100.0                       100
# 183                        NaN                        18
# 184                        NaN                       100
# 185                        NaN                        63
#
#     2013 : Preparedness Score 2012 : Preparedness Score  \
# 0                          10                         0
# 1                         NaN                       NaN
# 2                          61                        10
# 3                           8                        40
# 4                          25                       NaN
# ..                        ...                       ...
# 181                        80                        80
# 182                        90                        70
# 183                        18                        40
# 184                       100                       100
# 185                       NaN                       NaN
#
#     2011 : Preparedness Score 2010 : Preparedness Score Country Code  \
# 0                           0                        41          AFG
# 1                         NaN                       NaN          ALB
# 2                           0                        46          DZA
# 3                          10                        12          AND
# 4                          20                       NaN          AGO
# ..                        ...                       ...          ...
# 181                        10                       NaN          VEN
# 182                       100                        35          VNM
# 183                       NaN                       NaN          YEM
# 184                        67                       NaN          ZMB
# 185                        55                       NaN          ZWE
#
#       Country Name  2010 : Stat Capacity Score  2011 : Stat Capacity Score  \
# 0      Afghanistan                   52.222222                   51.111111
# 1          Albania                   70.000000                   70.000000
# 2          Algeria                   58.888889                   62.222222
# 3          Andorra                         NaN                         NaN
# 4           Angola                   45.555556                   47.777778
# ..             ...                         ...                         ...
# 181  Venezuela, RB                   83.333333                   78.888889
# 182        Vietnam                   64.444444                   71.111111
# 183    Yemen, Rep.                   48.888889                   47.777778
# 184         Zambia                   57.777778                   60.000000
# 185       Zimbabwe                   51.111111                   54.444444
#
#      2012 : Stat Capacity Score  2013 : Stat Capacity Score  \
# 0                     50.000000                   53.333333
# 1                     73.333333                   68.888889
# 2                     58.888889                   51.111111
# 3                           NaN                         NaN
# 4                     50.000000                   47.777778
# ..                          ...                         ...
# 181                   77.777778                   80.000000
# 182                   71.111111                   74.444444
# 183                   46.666667                   52.222222
# 184                   62.222222                   56.666667
# 185                   53.333333                   54.444444
#
#      2014 : Stat Capacity Score  2015 : Stat Capacity Score  \
# 0                     54.444444                   51.111100
# 1                     75.555556                   72.222233
# 2                     52.222222                   53.333367
# 3                           NaN                         NaN
# 4                     48.888889                   47.777767
# ..                          ...                         ...
# 181                   81.111111                   82.222233
# 182                   76.666667                   82.222233
# 183                   55.555556                   55.555600
# 184                   60.000000                   60.000033
# 185                   57.777778                   62.222200
#
#      2016 : Stat Capacity Score  2017 : Stat Capacity Score
# 0                     51.111100                   51.111100
# 1                     82.222233                   88.888900
# 2                     55.555567                   61.111100
# 3                           NaN                         NaN
# 4                     42.222167                   45.555500
# ..                          ...                         ...
# 181                   82.222233                   68.888900
# 182                   82.222233                   83.333333
# 183                   47.777833                   44.444467
# 184                   53.333367                   52.222233
# 185                   55.555533                   59.999967
#
# [186 rows x 18 columns]

# %%
new_combined_df = new_combined[["Country Name", "Country Code",
                                "2010 : Preparedness Score", "2010 : Stat Capacity Score",
                                "2011 : Preparedness Score", "2011 : Stat Capacity Score",
                                "2012 : Preparedness Score", "2012 : Stat Capacity Score",
                                "2013 : Preparedness Score", "2013 : Stat Capacity Score",
                                "2014 : Preparedness Score", "2014 : Stat Capacity Score",
                                "2015 : Preparedness Score", "2015 : Stat Capacity Score",
                                "2016 : Preparedness Score", "2016 : Stat Capacity Score",
                                "2017 : Preparedness Score", "2017 : Stat Capacity Score",]]
new_combined_df
# Out:
#       Country Name Country Code 2010 : Preparedness Score  \
# 0      Afghanistan          AFG                        41
# 1          Albania          ALB                       NaN
# 2          Algeria          DZA                        46
# 3          Andorra          AND                        12
# 4           Angola          AGO                       NaN
# ..             ...          ...                       ...
# 181  Venezuela, RB          VEN                       NaN
# 182        Vietnam          VNM                        35
# 183    Yemen, Rep.          YEM                       NaN
# 184         Zambia          ZMB                       NaN
# 185       Zimbabwe          ZWE                       NaN
#
#      2010 : Stat Capacity Score 2011 : Preparedness Score  \
# 0                     52.222222                         0
# 1                     70.000000                       NaN
# 2                     58.888889                         0
# 3                           NaN                        10
# 4                     45.555556                        20
# ..                          ...                       ...
# 181                   83.333333                        10
# 182                   64.444444                       100
# 183                   48.888889                       NaN
# 184                   57.777778                        67
# 185                   51.111111                        55
#
#      2011 : Stat Capacity Score 2012 : Preparedness Score  \
# 0                     51.111111                         0
# 1                     70.000000                       NaN
# 2                     62.222222                        10
# 3                           NaN                        40
# 4                     47.777778                       NaN
# ..                          ...                       ...
# 181                   78.888889                        80
# 182                   71.111111                        70
# 183                   47.777778                        40
# 184                   60.000000                       100
# 185                   54.444444                       NaN
#
#      2012 : Stat Capacity Score 2013 : Preparedness Score  \
# 0                     50.000000                        10
# 1                     73.333333                       NaN
# 2                     58.888889                        61
# 3                           NaN                         8
# 4                     50.000000                        25
# ..                          ...                       ...
# 181                   77.777778                        80
# 182                   71.111111                        90
# 183                   46.666667                        18
# 184                   62.222222                       100
# 185                   53.333333                       NaN
#
#      2013 : Stat Capacity Score 2014 : Preparedness Score  \
# 0                     53.333333                        26
# 1                     68.888889                       NaN
# 2                     51.111111                        80
# 3                           NaN                         8
# 4                     47.777778                         0
# ..                          ...                       ...
# 181                   80.000000                       100
# 182                   74.444444                       100
# 183                   52.222222                        18
# 184                   56.666667                       100
# 185                   54.444444                        63
#
#      2014 : Stat Capacity Score  2015 : Preparedness Score  \
# 0                     54.444444                       18.0
# 1                     75.555556                        NaN
# 2                     52.222222                       80.0
# 3                           NaN                        8.0
# 4                     48.888889                        NaN
# ..                          ...                        ...
# 181                   81.111111                      100.0
# 182                   76.666667                      100.0
# 183                   55.555556                        NaN
# 184                   60.000000                        NaN
# 185                   57.777778                        NaN
#
#      2015 : Stat Capacity Score  2016 : Preparedness Score  \
# 0                     51.111100                       28.0
# 1                     72.222233                        NaN
# 2                     53.333367                       63.0
# 3                           NaN                        8.0
# 4                     47.777767                        NaN
# ..                          ...                        ...
# 181                   82.222233                      100.0
# 182                   82.222233                      100.0
# 183                   55.555600                        NaN
# 184                   60.000033                        NaN
# 185                   62.222200                       80.0
#
#      2016 : Stat Capacity Score  2017 : Preparedness Score  \
# 0                     51.111100                       55.0
# 1                     82.222233                        8.0
# 2                     55.555567                       80.0
# 3                           NaN                        8.0
# 4                     42.222167                       90.0
# ..                          ...                        ...
# 181                   82.222233                      100.0
# 182                   82.222233                       92.0
# 183                   47.777833                       10.0
# 184                   53.333367                       73.0
# 185                   55.555533                       53.0
#
#      2017 : Stat Capacity Score
# 0                     51.111100
# 1                     88.888900
# 2                     61.111100
# 3                           NaN
# 4                     45.555500
# ..                          ...
# 181                   68.888900
# 182                   83.333333
# 183                   44.444467
# 184                   52.222233
# 185                   59.999967
#
# [186 rows x 18 columns]
